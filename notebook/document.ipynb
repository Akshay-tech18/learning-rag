# %% [markdown]
# ### Data Ingestion

# %%
###Document sturcture 

from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "This is the basic content i am using for or to create the RAG application for learning purpose",
    metadata={
        "source":"example",
        "pages":1,
        "author":"Akshay"
    }
)
doc
# Out:
# Document(metadata={'source': 'example', 'pages': 1, 'author': 'Akshay'}, page_content='This is the basic content i am using for or to create the RAG application for learning purpose')

# %%
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"Python is a high-level, interpreted, and general-purpose programming language known for its simple syntax and readability. Created by Guido van Rossum and first released in 1991, Python emphasizes code clarity, making it easy for beginners to learn while remaining powerful enough for professional software development. It supports multiple programming paradigms, including object-oriented, procedural, and functional programming. Python has a vast standard library and a rich ecosystem of third-party packages that enable developers to build web applications, automate tasks, analyze data, create machine learning models, develop games, and work with Internet of Things (IoT) devices. Popular frameworks and libraries such as Django, Flask, NumPy, and TensorFlow have contributed to Python's widespread adoption across industries. Due to its versatility, extensive community support, and cross-platform compatibility, Python remains one of the most popular programming languages in the world."
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample file is created")
# Out:
# Sample file is created

# %%
sample_texts={
    "../data/text_files/machine_learning.txt":"Machine Learning (ML) is a branch of Artificial Intelligence that enables computers to learn from data and improve their performance without being explicitly programmed for every task. Instead of following fixed instructions, machine learning algorithms identify patterns, make predictions, and adapt based on experience. ML is widely used in applications such as recommendation systems, image and speech recognition, fraud detection, medical diagnosis, autonomous vehicles, and natural language processing. The main types of machine learning include supervised learning, where models learn from labeled data; unsupervised learning, where patterns are discovered in unlabeled data; and reinforcement learning, where agents learn through rewards and penalties. Popular Python libraries such as Scikit-learn, TensorFlow, and PyTorch provide powerful tools for building and deploying machine learning models. As the availability of data and computing power continues to grow, machine learning is playing an increasingly important role in solving complex real-world problems and driving innovation across industries."
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample file is created")
# Out:
# Sample file is created

# %%
###Text loader

# from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader

laoder = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
doc = laoder.load()
print(doc)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="Python is a high-level, interpreted, and general-purpose programming language known for its simple syntax and readability. Created by Guido van Rossum and first released in 1991, Python emphasizes code clarity, making it easy for beginners to learn while remaining powerful enough for professional software development. It supports multiple programming paradigms, including object-oriented, procedural, and functional programming. Python has a vast standard library and a rich ecosystem of third-party packages that enable developers to build web applications, automate tasks, analyze data, create machine learning models, develop games, and work with Internet of Things (IoT) devices. Popular frameworks and libraries such as Django, Flask, NumPy, and TensorFlow have contributed to Python's widespread adoption across industries. Due to its versatility, extensive community support, and cross-platform compatibil
# ...

# %%
## Directory loader

from langchain_community.document_loaders import DirectoryLoader

dir_ = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding' : 'utf-8'},
    show_progress=False
)

docs = dir_.load()
print(docs)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="Python is a high-level, interpreted, and general-purpose programming language known for its simple syntax and readability. Created by Guido van Rossum and first released in 1991, Python emphasizes code clarity, making it easy for beginners to learn while remaining powerful enough for professional software development. It supports multiple programming paradigms, including object-oriented, procedural, and functional programming. Python has a vast standard library and a rich ecosystem of third-party packages that enable developers to build web applications, automate tasks, analyze data, create machine learning models, develop games, and work with Internet of Things (IoT) devices. Popular frameworks and libraries such as Django, Flask, NumPy, and TensorFlow have contributed to Python's widespread adoption across industries. Due to its versatility, extensive community support, and cross-platform compatibil
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_ = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf",
    loader_cls=PyMuPDFLoader,
    # loader_kwargs={'encoding' : 'utf-8'},
    show_progress=False
)

doc = dir_.load()
doc
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'TeX', 'creationdate': '2026-05-25T06:29:54+00:00', 'source': '../data/pdf/Devpilot Document.pdf', 'file_path': '../data/pdf/Devpilot Document.pdf', 'total_pages': 6, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-25T06:29:54+00:00', 'trapped': '', 'modDate': 'D:20260525062954Z', 'creationDate': 'D:20260525062954Z', 'page': 0}, page_content='DevPilot: An Intelligent GitHub-Driven Software\nProject Management and Defect Prediction System\n1st Given Name Surname\ndept. name of organization (of Aff.)\nname of organization (of Aff.)\nCity, Country\nemail address or ORCID\n2nd Given Name Surname\ndept. name of organization (of Aff.)\nname of organization (of Aff.)\nCity, Country\nemail address or ORCID\n3rd Given Name Surname\ndept. name of organization (of Aff.)\nname of organization (of Aff.)\nCity, Country\nemail address or ORCID\n4th Given Name Surname\ndept. name of organi
# ...
